# %%
## load in deepstarr 25k deeplift library for 3 seq idx

# %%
## show raw wt deepshap logo

# %%
## set up vbgmm but:
# p(x) = Nsum(Ksum(pi_k * gauss(x given mu_k and cov_k)) + gauss_bg(x given mu_bg and cov_bg)))
